# %% [markdown]
# <a href="https://colab.research.google.com/github/deepstride/python_learning/blob/main/Py_Spark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("=====Simple Calculator=====")
#user inputs
num1=float(input("Enter a number:"))
num2=float(input("Enter a number:"))
#Choose operation
print("Choose an operation:")
print("1.Addition")
print("2.Subtraction")
print("3.Multiplication")
print("4.Division")
#Performing Operations
choice=input("Enter your choice (1/2/3/4):")
if choice == "1":
  result = num1 + num2
  print(f"\nResult: {num1} + {num2} = {result}")
elif choice == "2":
  result = num1 - num2
  print(f"\nResult: {num1} - {num2} = {result}")
elif choice == "3":
  result = num1 * num2
  print(f"\nResult: {num1} * {num2} = {result}")
elif choice == "4":
  result = num1 / num2
  print(f"\nResult: {num1} / {num2} = {result}")
else:
  print("Invalid choice!")
# Out:
# =====Simple Calculator=====
# Enter a number:12
# Enter a number:3
# Choose an operation:
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# Enter your choice (1/2/3/4):3
#
# Result: 12.0 * 3.0 = 36.0
